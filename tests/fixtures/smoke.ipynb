# %% [markdown]
# # Smoke Test Notebook
#
# Exercises **markdown**, `code`, streams, errors, and images.
#
# - item one
# - item two

# %%
print('hello from rustlab')
2 + 2

# %%
print('\x1b[31mred text\x1b[0m and \x1b[1;34mbold blue\x1b[0m')

# %%
1 / 0

# %%
import time
for i in range(3):
    print(f'tick {i}')
    time.sleep(0.2)
